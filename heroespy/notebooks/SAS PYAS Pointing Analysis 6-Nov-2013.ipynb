# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import pandas
import matplotlib.pyplot as plt
import numpy as np
import sunpy
import matplotlib
import seaborn as sns
from scipy import stats
# Out:
# /Users/schriste/anaconda/lib/python2.7/site-packages/pytz/__init__.py:35: UserWarning: Module _imaging was already imported from /Users/schriste/anaconda/lib/python2.7/site-packages/PIL/_imaging.so, but /Users/schriste/.local/lib/python2.7/site-packages is being added to sys.path
#   from pkg_resources import resource_stream

# %%
sns.set_color_palette("deep", desat=.6)

# %%
import heroespy

# %% [markdown]
# First load the data, this loads all of the data from all the solar observations, these files can be recreated using the script inside notebooks called

# %%
date_format = "%Y-%m-%d %H:%M:%S.%f"

# %%
data = pandas.read_csv("/Users/schriste/Dropbox/Developer/HEROES/HEROES-Telescope/SAS1_pointing_data.csv", parse_dates=True, index_col = 0)

# %%
data
# Out:
# WARNING: DeprecationWarning: height has been deprecated.
#  [pandas.core.config]
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 101820 entries, 2013-09-21 15:37:44.709049 to 2013-09-21 22:35:54.476023
# Data columns (total 7 columns):
# offset r       101820  non-null values
# offset x       101820  non-null values
# offset y       101820  non-null values
# pointing az    101820  non-null values
# pointing el    101820  non-null values
# pointing x     101820  non-null values
# pointing y     101820  non-null values
# dtypes: float64(7)

# %% [markdown]
# Get rid of outliers

# %%
data.describe()
# Out:
# WARNING: DeprecationWarning: height has been deprecated.
#  [pandas.core.config]
# WARNING: DeprecationWarning: height has been deprecated.
#  [pandas.core.config]
# WARNING: DeprecationWarning: height has been deprecated.
#  [pandas.core.config]
#             offset r       offset x       offset y    pointing az  \
# count  101820.000000  101820.000000  101820.000000  101820.000000
# mean       35.288443      13.720471      -0.601327     461.552716
# std        55.943465      55.197424      33.757773     298.575444
# min         0.153758   -2375.628042    -243.421328   -2296.241712
# 25%        17.137125      -4.386327     -13.691031     156.853384
# 50%        28.118357      12.128072      -0.684382     524.787603
# 75%        43.092491      28.738424      12.217639     757.533108
# max      3478.211166     794.000000    2540.540163     974.883295
#
#          pointing el     pointing x     pointing y
# count  101820.000000  101820.000000  101820.000000
# mean      460.285182    -769.003512      99.950117
# std       316.433926     107.434117      35.648753
# min      -265.489180   -3169.628042    -153.527507
# 25%       147.497858    -797.884348      87.764951
# 50%       562.766135    -781.353115     100.970168
# 75%       755.425615    -764.545850     113.889298
# max      3428.824061     122.666138    2642.540163

# %% [markdown]
# The large max values suggest that we have some bad data which we should get rid of

# %%
5*data['offset x'].std()
# Out:
# 275.98712191181875

# %%
con1 = np.abs(data['offset x']) < 5*data['offset x'].std()
con2 = np.abs(data['offset y']) < 5*data['offset y'].std()
index = (con1 * con2) == 1

# %%
np.sum(index)
# Out:
# 101444

# %% [markdown]
# Number of bad values

# %%
np.sum(index == False)
# Out:
# 376

# %%
clean_data = data[index]
clean_data.describe()
# Out:
# WARNING: DeprecationWarning: height has been deprecated.
#  [pandas.core.config]
# WARNING: DeprecationWarning: height has been deprecated.
#  [pandas.core.config]
# WARNING: DeprecationWarning: height has been deprecated.
#  [pandas.core.config]
#             offset r       offset x       offset y    pointing az  \
# count  101444.000000  101444.000000  101444.000000  101444.000000
# mean       32.448952      11.520651      -0.543089     463.328169
# std        21.249934      27.082339      25.259253     296.849078
# min         0.153758    -180.979351    -167.186745    -166.261230
# 25%        17.101420      -4.442132     -13.532464     159.227057
# 50%        28.027330      12.040397      -0.612949     527.471969
# 75%        42.874182      28.548171      12.250527     757.798764
# max       286.971154     256.454461     168.447872     974.883295
#
#          pointing el     pointing x     pointing y
# count  101444.000000  101444.000000  101444.000000
# mean      461.537982    -771.192846     100.007007
# std       314.626891      96.370422      27.765899
# min      -248.741745    -974.979351    -153.527507
# 25%       150.899576    -797.927121      87.913494
# 50%       564.955792    -781.453866     101.041826
# 75%       755.596988    -764.729032     113.910901
# max       971.008541     122.666138     267.135965

# %%
col = 'pointing az'
fig = plt.figure(figsize=(8,6), dpi=100)
clean_data[col].plot()

# %%
fig = plt.figure(figsize=(8,6), dpi=100)
clean_data[col][10000:12000].plot()

# %%
col = 'pointing el'
fig = plt.figure(figsize=(8,6), dpi=100)
clean_data[col].plot()

# %%
col = 'pointing az'
fig = plt.figure(figsize=(8,6), dpi=100)
ax1 = sns.distplot(clean_data[col], bins=100, kde=False, fit=stats.norm, legend = True)
ax1.legend()
ax1.set_title('HEROES/SAS PYAS-F $x_{mean}$ = ' + str(clean_data[col].mean()) + ' $\sigma_x$ = ' + str(clean_data[col].std())[0:6])
ax1.set_xlabel(col + ' [arcsec]')
plt.show()

# %%
col = 'pointing el'
fig = plt.figure(figsize=(8,6), dpi=100)
ax1 = sns.distplot(clean_data[col], bins=100, kde=False, fit=stats.norm, legend = True)
ax1.legend()
ax1.set_title('HEROES/SAS PYAS-F $x_{mean}$ = ' + str(clean_data[col].mean()) + ' $\sigma_x$ = ' + str(clean_data[col].std())[0:6])
ax1.set_xlabel(col + ' [arcsec]')
plt.show()

# %%
col = 'offset x'
fig = plt.figure(figsize=(8,6), dpi=100)
ax1 = sns.distplot(clean_data[col], bins=100, kde=False, fit=stats.norm, legend = True)
ax1.legend()
ax1.set_title('HEROES/SAS PYAS-F $x_{mean}$ = ' + str(clean_data[col].mean()) + ' $\sigma_x$ = ' + str(clean_data[col].std())[0:6])
ax1.set_xlabel(col + ' [arcsec]')
plt.show()

# %%
fig = plt.figure(figsize=(8,6), dpi=100)
clean_data[col].plot()

# %%
fig = plt.figure(figsize=(8,6), dpi=100)
clean_data[col][10000:12000].plot()

# %%
col = 'offset y'
fig = plt.figure(figsize=(8,6), dpi=100)
ax1 = sns.distplot(clean_data[col], bins=100, kde=False, fit=stats.norm, legend = True)
ax1.legend()
ax1.set_title('HEROES/SAS PYAS-F $x_{mean}$ = ' + str(clean_data[col].mean()) + ' $\sigma_x$ = ' + str(clean_data[col].std())[0:6])
ax1.set_xlabel(col + ' [arcsec]')
plt.show()

# %%
col = 'offset r'
fig = plt.figure(figsize=(8,6), dpi=100)
ax1 = sns.distplot(clean_data[col], bins=100, kde=True, legend = True)
ax1.legend()
ax1.set_title('HEROES/SAS PYAS-F $x_{mean}$ = ' + str(clean_data[col].mean()) + ' $\sigma_x$ = ' + str(clean_data[col].std())[0:6])
ax1.set_xlabel(col + ' [arcsec]')
plt.show()

# %% [markdown]
# Now lets plot the pointing accuracy over the entire solar observation as an offset from the target

# %%
heatmap, xedges, yedges = np.histogram2d(clean_data['offset x'].values, clean_data['offset y'].values, bins=200)
extent = [yedges[0], yedges[-1], xedges[-1], xedges[0]]
fig, ax = plt.subplots(figsize=(8,6), dpi=100)
cax = ax.hist2d(clean_data['offset x'].values, clean_data['offset y'].values, bins=100, cmap = "PuRd")
#ax.contour(kde2d, extent = extent)
ax.set_title('HEROES/SAS PYAS-F')
ax.set_xlabel('Heliospheric Offset X [arcsec]')
ax.set_ylabel('Heliospheric Offset Y [arcsec]')
ax.set_xlim(-100,100)
ax.set_ylim(-100,100)
plt.show()

# %%
from sunpy.map import Map
file = '/Users/schriste/Downloads/aia.lev1.193A_2013-09-21T16_00_06.84Z.image_lev1.fits'
map = Map(file)
fov = 9*60
target = np.array([-794., 102])
corner = target - fov/2.0
xrange = corner[0] + np.array([0, fov])
yrange = corner[1] + np.array([0, fov])
smap = map.submap(xrange, yrange)
 
heatmap, xedges, yedges = np.histogram2d(clean_data['pointing y'].values, clean_data['pointing x'].values, bins=200)
extent = [yedges[0], yedges[-1], xedges[-1], xedges[0]]
# Out:
# WARNING: Converting Quantity object in units 'kg3 m N' to a Numpy array [astropy.units.quantity]

# %%
heatmap.max(), heatmap.min()
# Out:
# (547.0, 0.0)

# %%
masked_data = np.ma.masked_where(heatmap < 10, heatmap)

# %%
fig, ax = plt.subplots(figsize=(15,10), dpi=100)
cax = smap.plot()
smap.draw_limb()
ax.plot(target[0], target[1], "w+")
ax.imshow(masked_data, extent = extent, alpha = 0.5, cmap = plt.get_cmap('jet_r'))
ax.set_xbound(xrange[0], xrange[1])
ax.set_ybound(yrange[0], yrange[1])
plt.show()
